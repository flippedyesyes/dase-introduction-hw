# %%
#1. 删除重复数据，并输出去重前后的数据量
import pandas as pd
raw_data = pd.read_csv('github_bot_raw_data.csv') 
#列字段解读
columns = [
    'actor_id',  # GitHub用户的ID (示例值: 1081405)
    'label',  # 用户标签（"Human"或"Bot"） (示例值: Human)
    'login',  # GitHub用户的登录名 (示例值: dlazesz)
    'id',  # 用户的GitHub ID (示例值: 1081405)
    'node_id',  # 用户的GitHub节点ID (示例值: MDQ6VXNlcjEwODE0MDU=)
    'avatar_url',  # GitHub头像URL (示例值: https://avatars.githubusercontent.com/u/1081405?v=4)
    'gravatar_id',  # Gravatar ID (示例值: None)
    'url',  # GitHub用户的URL (示例值: https://api.github.com/users/dlazesz)
    'html_url',  # GitHub用户的HTML URL (示例值: https://github.com/dlazesz)
    'followers_url',  # GitHub用户的粉丝URL (示例值: https://api.github.com/users/dlazesz/followers)
    'following_url',  # GitHub用户的关注URL (示例值: https://api.github.com/users/dlazesz/following{/other_user})
    'gists_url',  # 用户的GitHub Gists URL (示例值: https://api.github.com/users/dlazesz/gists{/gist_id})
    'starred_url',  # 用户的GitHub Starred URL (示例值: https://api.github.com/users/dlazesz/starred{/owner}{/repo})
    'subscriptions_url',  # 用户的GitHub订阅URL (示例值: https://api.github.com/users/dlazesz/subscriptions)
    'organizations_url',  # 用户的GitHub组织URL (示例值: https://api.github.com/users/dlazesz/orgs)
    'repos_url',  # 用户的GitHub仓库URL (示例值: https://api.github.com/users/dlazesz/repos)
    'events_url',  # 用户的GitHub事件URL (示例值: https://api.github.com/users/dlazesz/events{/privacy})
    'received_events_url',  # 用户的GitHub接收事件URL (示例值: https://api.github.com/users/dlazesz/received_events)
    'type',  # 用户类型，通常为"User" (示例值: User)
    'site_admin',  # 表示用户是否是GitHub网站管理员的标志 (示例值: False)
    'name',  # 用户的姓名 (示例值: Indig Balázs)
    'company',  # 用户所在公司 (示例值: None)
    'blog',  # 用户的博客 (示例值: None)
    'location',  # 用户的位置 (示例值: None)
    'email',  # 用户的电子邮件 (示例值: None)
    'hireable',  # 表示用户是否愿意被雇佣的标志 (示例值: None)
    'bio',  # 用户在其GitHub资料中提供的自我介绍或个人简介 (示例值: None)
    'twitter_username',  # 用户的Twitter用户名 (示例值: None)
    'public_repos',  # 用户在GitHub上的公共代码仓库数量 (示例值: 26)
    'public_gists',  # 用户的公共Gists数量 (示例值: 1)
    'followers',  # 关注该用户的其他GitHub用户数量 (示例值: 5)
    'following',  # 该用户关注的其他GitHub用户数量 (示例值: 1)
    'created_at',  # 用户的GitHub帐户创建日期 (示例值: 2011-09-26T17:27:03Z)
    'updated_at',  # 用户的GitHub帐户最后更新日期 (示例值: 2023-10-13T11:21:10Z)
]
data = raw_data[columns]
# 输出去重前的数据量
print(f"去重前的数据量: {len(data)}")

# 删除重复数据
data = data.drop_duplicates()

# 输出去重后的数据量
print(f"去重后的数据量: {len(data)}")
# Out:
# 去重前的数据量: 20358
# 去重后的数据量: 19779

# %%
#2首先，去掉 gravatar_id 列，并查看各列的缺失值的情况
#其次，将可转化成 boolean 变量的列字段转化成 boolean 变量（转成布尔类型是为了便于处理缺失字段，如是否存在公司、位置等等），文本数据用空字符串填充空值......
#最后，再次看各列有无缺失值
import pandas as pd
raw_data = pd.read_csv('github_bot_raw_data.csv') 
#列字段解读
columns = [
    'actor_id',  # GitHub用户的ID (示例值: 1081405)
    'label',  # 用户标签（"Human"或"Bot"） (示例值: Human)
    'login',  # GitHub用户的登录名 (示例值: dlazesz)
    'id',  # 用户的GitHub ID (示例值: 1081405)
    'node_id',  # 用户的GitHub节点ID (示例值: MDQ6VXNlcjEwODE0MDU=)
    'avatar_url',  # GitHub头像URL (示例值: https://avatars.githubusercontent.com/u/1081405?v=4)
    'gravatar_id',  # Gravatar ID (示例值: None)
    'url',  # GitHub用户的URL (示例值: https://api.github.com/users/dlazesz)
    'html_url',  # GitHub用户的HTML URL (示例值: https://github.com/dlazesz)
    'followers_url',  # GitHub用户的粉丝URL (示例值: https://api.github.com/users/dlazesz/followers)
    'following_url',  # GitHub用户的关注URL (示例值: https://api.github.com/users/dlazesz/following{/other_user})
    'gists_url',  # 用户的GitHub Gists URL (示例值: https://api.github.com/users/dlazesz/gists{/gist_id})
    'starred_url',  # 用户的GitHub Starred URL (示例值: https://api.github.com/users/dlazesz/starred{/owner}{/repo})
    'subscriptions_url',  # 用户的GitHub订阅URL (示例值: https://api.github.com/users/dlazesz/subscriptions)
    'organizations_url',  # 用户的GitHub组织URL (示例值: https://api.github.com/users/dlazesz/orgs)
    'repos_url',  # 用户的GitHub仓库URL (示例值: https://api.github.com/users/dlazesz/repos)
    'events_url',  # 用户的GitHub事件URL (示例值: https://api.github.com/users/dlazesz/events{/privacy})
    'received_events_url',  # 用户的GitHub接收事件URL (示例值: https://api.github.com/users/dlazesz/received_events)
    'type',  # 用户类型，通常为"User" (示例值: User)
    'site_admin',  # 表示用户是否是GitHub网站管理员的标志 (示例值: False)
    'name',  # 用户的姓名 (示例值: Indig Balázs)
    'company',  # 用户所在公司 (示例值: None)
    'blog',  # 用户的博客 (示例值: None)
    'location',  # 用户的位置 (示例值: None)
    'email',  # 用户的电子邮件 (示例值: None)
    'hireable',  # 表示用户是否愿意被雇佣的标志 (示例值: None)
    'bio',  # 用户在其GitHub资料中提供的自我介绍或个人简介 (示例值: None)
    'twitter_username',  # 用户的Twitter用户名 (示例值: None)
    'public_repos',  # 用户在GitHub上的公共代码仓库数量 (示例值: 26)
    'public_gists',  # 用户的公共Gists数量 (示例值: 1)
    'followers',  # 关注该用户的其他GitHub用户数量 (示例值: 5)
    'following',  # 该用户关注的其他GitHub用户数量 (示例值: 1)
    'created_at',  # 用户的GitHub帐户创建日期 (示例值: 2011-09-26T17:27:03Z)
    'updated_at',  # 用户的GitHub帐户最后更新日期 (示例值: 2023-10-13T11:21:10Z)
]
data = raw_data[columns]

# 删除重复数据
data = data.drop_duplicates()

# 去掉 gravatar_id 列
data = data.drop(columns=['gravatar_id'])

# 查看各列的缺失值情况
print("去重前各列的缺失值情况:")
print(data.isnull().sum())

# 将可转化成 boolean 变量的列字段转化成 boolean 变量
boolean_columns = ['company', 'blog', 'location', 'email', 'hireable', 'bio', 'twitter_username']
for col in boolean_columns:
    data[col] = ~data[col].isnull()

# 文本数据用空字符串填充空值
text_columns = ['name', 'company', 'blog', 'location', 'email', 'bio', 'twitter_username']
for col in text_columns:
    data[col] = data[col].fillna('')

# 再次查看各列的缺失值情况
print("处理后各列的缺失值情况:")
print(data.isnull().sum())
# Out:
# 去重前各列的缺失值情况:
# actor_id                   0
# label                      0
# login                      0
# id                         0
# node_id                    0
# avatar_url                 0
# url                        0
# html_url                   0
# followers_url              0
# following_url              0
# gists_url                  0
# starred_url                0
# subscriptions_url          0
# organizations_url          0
# repos_url                  0
# events_url                 0
# received_events_url        0
# type                       0
# site_admin                 0
# name                    2589
# company                 8982
# blog                   11263
# location                7080
# email                  11739
# hireable               16481
# bio                    10930
# twitter_username       14859
# public_repos               0
# public_gists               0
# followers                  0
# following                  0
# ...

# %%
#3数据变换，将created_at、updated_at转为时间戳
import pandas as pd

# 读取CSV文件
raw_data = pd.read_csv('github_bot_raw_data.csv')

# 定义列字段
columns = [
    'actor_id',  # GitHub用户的ID
    'label',  # 用户标签（"Human"或"Bot"）
    'login',  # GitHub用户的登录名
    'id',  # 用户的GitHub ID
    'node_id',  # 用户的GitHub节点ID
    'avatar_url',  # GitHub头像URL
    'gravatar_id',  # Gravatar ID
    'url',  # GitHub用户的URL
    'html_url',  # GitHub用户的HTML URL
    'followers_url',  # GitHub用户的粉丝URL
    'following_url',  # GitHub用户的关注URL
    'gists_url',  # 用户的GitHub Gists URL
    'starred_url',  # 用户的GitHub Starred URL
    'subscriptions_url',  # 用户的GitHub订阅URL
    'organizations_url',  # 用户的GitHub组织URL
    'repos_url',  # 用户的GitHub仓库URL
    'events_url',  # 用户的GitHub事件URL
    'received_events_url',  # 用户的GitHub接收事件URL
    'type',  # 用户类型，通常为"User"
    'site_admin',  # 表示用户是否是GitHub网站管理员的标志
    'name',  # 用户的姓名
    'company',  # 用户所在公司
    'blog',  # 用户的博客
    'location',  # 用户的位置
    'email',  # 用户的电子邮件
    'hireable',  # 表示用户是否愿意被雇佣的标志
    'bio',  # 用户在其GitHub资料中提供的自我介绍或个人简介
    'twitter_username',  # 用户的Twitter用户名
    'public_repos',  # 用户在GitHub上的公共代码仓库数量
    'public_gists',  # 用户的公共Gists数量
    'followers',  # 关注该用户的其他GitHub用户数量
    'following',  # 该用户关注的其他GitHub用户数量
    'created_at',  # 用户的GitHub帐户创建日期
    'updated_at'  # 用户的GitHub帐户最后更新日期
]

# 选择指定的列
data = raw_data[columns]

# 删除重复数据
data = data.drop_duplicates()

# 去掉 gravatar_id 列
data = data.drop(columns=['gravatar_id'])

# 将可转化成 boolean 变量的列字段转化成 boolean 变量
boolean_columns = ['company', 'blog', 'location', 'email', 'hireable', 'bio', 'twitter_username']
for col in boolean_columns:
    data[col] = ~data[col].isnull()

# 文本数据用空字符串填充空值
text_columns = ['name', 'company', 'blog', 'location', 'email', 'bio', 'twitter_username']
for col in text_columns:
    data[col] = data[col].fillna('')

data['created_at'] = pd.to_datetime(data['created_at'], errors='coerce')  
data['updated_at'] = pd.to_datetime(data['updated_at'], errors='coerce')

data['created_at_timestamp'] = data['created_at'].view('int64') // 10**9
data['updated_at_timestamp'] = data['updated_at'].view('int64') // 10**9

# 查看转换后的数据
print("转换后的数据:")
print(data.head())
# Out:
# 转换后的数据:
#    actor_id  label      login        id               node_id  \
# 0   1081405  Human    dlazesz   1081405  MDQ6VXNlcjEwODE0MDU=
# 1  13100598  Human  sarkiroka  13100598  MDQ6VXNlcjEzMTAwNTk4
# 2     22494  Human  ZoomQuiet     22494      MDQ6VXNlcjIyNDk0
# 3   7648032    Bot   AlCutter   7648032  MDQ6VXNlcjc2NDgwMzI=
# 4   2163522  Human    meetyan   2163522  MDQ6VXNlcjIxNjM1MjI=
#
#                                           avatar_url  \
# 0  https://avatars.githubusercontent.com/u/108140...
# 1  https://avatars.githubusercontent.com/u/131005...
# 2  https://avatars.githubusercontent.com/u/22494?v=4
# 3  https://avatars.githubusercontent.com/u/764803...
# 4  https://avatars.githubusercontent.com/u/216352...
#
#                                       url                      html_url  \
# 0    https://api.github.com/users/dlazesz    https://github.com/dlazesz
# 1  https://api.github.com/users/sarkiroka  https://github.com/sarkiroka
# ...

# %%
#4.1可视化bot和hunman类型的情况（展示图表自选，并在报告中说明选择原因、结果分析以及数据洞察）
import pandas as pd
import matplotlib.pyplot as plt

# 读取CSV文件
raw_data = pd.read_csv('github_bot_raw_data.csv')

# 定义列字段
columns = [
    'actor_id',  # GitHub用户的ID
    'label',  # 用户标签（"Human"或"Bot"）
    'login',  # GitHub用户的登录名
    'id',  # 用户的GitHub ID
    'node_id',  # 用户的GitHub节点ID
    'avatar_url',  # GitHub头像URL
    'gravatar_id',  # Gravatar ID
    'url',  # GitHub用户的URL
    'html_url',  # GitHub用户的HTML URL
    'followers_url',  # GitHub用户的粉丝URL
    'following_url',  # GitHub用户的关注URL
    'gists_url',  # 用户的GitHub Gists URL
    'starred_url',  # 用户的GitHub Starred URL
    'subscriptions_url',  # 用户的GitHub订阅URL
    'organizations_url',  # 用户的GitHub组织URL
    'repos_url',  # 用户的GitHub仓库URL
    'events_url',  # 用户的GitHub事件URL
    'received_events_url',  # 用户的GitHub接收事件URL
    'type',  # 用户类型，通常为"User"
    'site_admin',  # 表示用户是否是GitHub网站管理员的标志
    'name',  # 用户的姓名
    'company',  # 用户所在公司
    'blog',  # 用户的博客
    'location',  # 用户的位置
    'email',  # 用户的电子邮件
    'hireable',  # 表示用户是否愿意被雇佣的标志
    'bio',  # 用户在其GitHub资料中提供的自我介绍或个人简介
    'twitter_username',  # 用户的Twitter用户名
    'public_repos',  # 用户在GitHub上的公共代码仓库数量
    'public_gists',  # 用户的公共Gists数量
    'followers',  # 关注该用户的其他GitHub用户数量
    'following',  # 该用户关注的其他GitHub用户数量
    'created_at',  # 用户的GitHub帐户创建日期
    'updated_at'  # 用户的GitHub帐户最后更新日期
]

# 选择指定的列
data = raw_data[columns]

# 删除重复数据
data = data.drop_duplicates()

# 去掉 gravatar_id 列
data = data.drop(columns=['gravatar_id'])

# 将可转化成 boolean 变量的列字段转化成 boolean 变量
boolean_columns = ['company', 'blog', 'location', 'email', 'hireable', 'bio', 'twitter_username']
for col in boolean_columns:
    data[col] = ~data[col].isnull()

# 文本数据用空字符串填充空值
text_columns = ['name', 'company', 'blog', 'location', 'email', 'bio', 'twitter_username']
for col in text_columns:
    data[col] = data[col].fillna('')

data['created_at'] = pd.to_datetime(data['created_at'], errors='coerce')  
data['updated_at'] = pd.to_datetime(data['updated_at'], errors='coerce')

data['created_at_timestamp'] = data['created_at'].view('int64') // 10**9
data['updated_at_timestamp'] = data['updated_at'].view('int64') // 10**9
# 查看 label 列的分布情况
label_counts = data['label'].value_counts()

# 打印数量
print("Bot and Human Types Distribution:")
print(label_counts)

# 生成饼状图
plt.figure(figsize=(8, 6))
plt.pie(label_counts, labels=label_counts.index, autopct='%1.1f%%', startangle=140, colors=['skyblue', 'salmon'])
plt.title('Bot and Human Types Distribution')
plt.axis('equal')  # 使饼图保持圆形
plt.show()

#选择原因：饼状图能清晰地展示出比例关系
#结果分析：显示 Human 占 94.0%，Bot 占 6.0%。
#数据洞察：human 用户的数量远多于 bot 用户。这表明 human 用户是 GitHub 的主要用户群体
# Out:
# Bot and Human Types Distribution:
# label
# Human    18588
# Bot       1191
# Name: count, dtype: int64

# %%
#4.2 可视化bot类型账号的created_at情况（展示图表自选，并在报告中说明选择原因、结果分析以及数据洞察）
import pandas as pd
import matplotlib.pyplot as plt

# 读取CSV文件
raw_data = pd.read_csv('github_bot_raw_data.csv')

# 定义列字段
columns = [
    'actor_id',  # GitHub用户的ID
    'label',  # 用户标签（"Human"或"Bot"）
    'login',  # GitHub用户的登录名
    'id',  # 用户的GitHub ID
    'node_id',  # 用户的GitHub节点ID
    'avatar_url',  # GitHub头像URL
    'gravatar_id',  # Gravatar ID
    'url',  # GitHub用户的URL
    'html_url',  # GitHub用户的HTML URL
    'followers_url',  # GitHub用户的粉丝URL
    'following_url',  # GitHub用户的关注URL
    'gists_url',  # 用户的GitHub Gists URL
    'starred_url',  # 用户的GitHub Starred URL
    'subscriptions_url',  # 用户的GitHub订阅URL
    'organizations_url',  # 用户的GitHub组织URL
    'repos_url',  # 用户的GitHub仓库URL
    'events_url',  # 用户的GitHub事件URL
    'received_events_url',  # 用户的GitHub接收事件URL
    'type',  # 用户类型，通常为"User"
    'site_admin',  # 表示用户是否是GitHub网站管理员的标志
    'name',  # 用户的姓名
    'company',  # 用户所在公司
    'blog',  # 用户的博客
    'location',  # 用户的位置
    'email',  # 用户的电子邮件
    'hireable',  # 表示用户是否愿意被雇佣的标志
    'bio',  # 用户在其GitHub资料中提供的自我介绍或个人简介
    'twitter_username',  # 用户的Twitter用户名
    'public_repos',  # 用户在GitHub上的公共代码仓库数量
    'public_gists',  # 用户的公共Gists数量
    'followers',  # 关注该用户的其他GitHub用户数量
    'following',  # 该用户关注的其他GitHub用户数量
    'created_at',  # 用户的GitHub帐户创建日期
    'updated_at'  # 用户的GitHub帐户最后更新日期
]

# 选择指定的列
data = raw_data[columns]

# 删除重复数据
data = data.drop_duplicates()

# 去掉 gravatar_id 列
data = data.drop(columns=['gravatar_id'])

# 将可转化成 boolean 变量的列字段转化成 boolean 变量
boolean_columns = ['company', 'blog', 'location', 'email', 'hireable', 'bio', 'twitter_username']
for col in boolean_columns:
    data[col] = ~data[col].isnull()

# 文本数据用空字符串填充空值
text_columns = ['name', 'company', 'blog', 'location', 'email', 'bio', 'twitter_username']
for col in text_columns:
    data[col] = data[col].fillna('')

data['created_at'] = pd.to_datetime(data['created_at'], errors='coerce')  
data['updated_at'] = pd.to_datetime(data['updated_at'], errors='coerce')

data['created_at_timestamp'] = data['created_at'].view('int64') // 10**9
data['updated_at_timestamp'] = data['updated_at'].view('int64') // 10**9
# 查看 label 列的分布情况
label_counts = data['label'].value_counts()

# 筛选出bot类型的账号
bot_data = data[data['label'] == 'Bot']

# 将created_at列转换为日期时间格式
bot_data['created_at'] = pd.to_datetime(bot_data['created_at'])

# 按月统计bot账号的创建数量
bot_data['year_month'] = bot_data['created_at'].dt.to_period('M')
bot_counts = bot_data['year_month'].value_counts().sort_index()

# 生成折线图
plt.figure(figsize=(12, 6))
plt.plot(bot_counts.index.astype(str), bot_counts.values, marker='o', linestyle='-')
plt.title('Bot Accounts Created Over Time')
plt.xlabel('Year-Month')
plt.ylabel('Number of Bot Accounts Created')
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()



#选择原因：折线图适合展示时间序列数据的趋势变化，能够直观地显示 bot 账号的创建时间分布趋势。
#结果分析：bot 账号的创建数量在某些月份有明显的增长或下降，bot账号 在2020 年 1 月附近有明显的增加。
#数据洞察：bot 账号的创建数量在某些时间段内有明显的增长趋势，这可能与特定的活动或事件有关，例如 GitHub 推出了新的自动化工具或功能。如果在某些时间段内 bot 账号的创建数量突然下降，可能是因为 GitHub 对 bot 账号的审核和管理政策发生了变化。
# Out:
# C:\Users\flipp\AppData\Local\Temp\ipykernel_4228\1040327036.py:77: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bot_data['created_at'] = pd.to_datetime(bot_data['created_at'])
# C:\Users\flipp\AppData\Local\Temp\ipykernel_4228\1040327036.py:80: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   bot_data['year_month'] = bot_data['created_at'].dt.to_period('M')
# C:\Users\flipp\AppData\Local\Temp\ipykernel_4228\1040327036.py:80: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
#4.3 可视化human类型账号的created_at情况（展示图表自选，并在报告中说明选择原因、结果分析以及数据洞察）
import pandas as pd
import matplotlib.pyplot as plt

# 读取CSV文件
raw_data = pd.read_csv('github_bot_raw_data.csv')

# 定义列字段
columns = [
    'actor_id',  # GitHub用户的ID
    'label',  # 用户标签（"Human"或"Bot"）
    'login',  # GitHub用户的登录名
    'id',  # 用户的GitHub ID
    'node_id',  # 用户的GitHub节点ID
    'avatar_url',  # GitHub头像URL
    'gravatar_id',  # Gravatar ID
    'url',  # GitHub用户的URL
    'html_url',  # GitHub用户的HTML URL
    'followers_url',  # GitHub用户的粉丝URL
    'following_url',  # GitHub用户的关注URL
    'gists_url',  # 用户的GitHub Gists URL
    'starred_url',  # 用户的GitHub Starred URL
    'subscriptions_url',  # 用户的GitHub订阅URL
    'organizations_url',  # 用户的GitHub组织URL
    'repos_url',  # 用户的GitHub仓库URL
    'events_url',  # 用户的GitHub事件URL
    'received_events_url',  # 用户的GitHub接收事件URL
    'type',  # 用户类型，通常为"User"
    'site_admin',  # 表示用户是否是GitHub网站管理员的标志
    'name',  # 用户的姓名
    'company',  # 用户所在公司
    'blog',  # 用户的博客
    'location',  # 用户的位置
    'email',  # 用户的电子邮件
    'hireable',  # 表示用户是否愿意被雇佣的标志
    'bio',  # 用户在其GitHub资料中提供的自我介绍或个人简介
    'twitter_username',  # 用户的Twitter用户名
    'public_repos',  # 用户在GitHub上的公共代码仓库数量
    'public_gists',  # 用户的公共Gists数量
    'followers',  # 关注该用户的其他GitHub用户数量
    'following',  # 该用户关注的其他GitHub用户数量
    'created_at',  # 用户的GitHub帐户创建日期
    'updated_at'  # 用户的GitHub帐户最后更新日期
]

# 选择指定的列
data = raw_data[columns]

# 删除重复数据
data = data.drop_duplicates()

# 去掉 gravatar_id 列
data = data.drop(columns=['gravatar_id'])

# 将可转化成 boolean 变量的列字段转化成 boolean 变量
boolean_columns = ['company', 'blog', 'location', 'email', 'hireable', 'bio', 'twitter_username']
for col in boolean_columns:
    data[col] = ~data[col].isnull()

# 文本数据用空字符串填充空值
text_columns = ['name', 'company', 'blog', 'location', 'email', 'bio', 'twitter_username']
for col in text_columns:
    data[col] = data[col].fillna('')

data['created_at'] = pd.to_datetime(data['created_at'], errors='coerce')  
data['updated_at'] = pd.to_datetime(data['updated_at'], errors='coerce')

data['created_at_timestamp'] = data['created_at'].view('int64') // 10**9
data['updated_at_timestamp'] = data['updated_at'].view('int64') // 10**9
# 查看 label 列的分布情况
label_counts = data['label'].value_counts()

# 筛选出human类型的账号
human_data = data[data['label'] == 'Human']

# 将created_at列转换为日期时间格式
human_data['created_at'] = pd.to_datetime(human_data['created_at'])

# 按月统计human账号的创建数量
human_data['year_month'] = human_data['created_at'].dt.to_period('M')
human_counts = human_data['year_month'].value_counts().sort_index()

# 生成折线图
plt.figure(figsize=(12, 6))
plt.plot(human_counts.index.astype(str), human_counts.values, marker='o', linestyle='-')
plt.title('Human Accounts Created Over Time')
plt.xlabel('Year-Month')
plt.ylabel('Number of Human Accounts Created')
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

#选择原因：折线图适合展示时间序列数据的趋势变化，能够直观地显示 human 账号的创建时间分布趋势。
#结果分析：human 账号的创建数量在某些月份有明显的增长或下降，human账号 在2016 年 1 月附近有明显的增加。
#数据洞察：human 账号的创建数量在某些时间段内有明显的增长趋势，这可能与特定的活动或事件有关，例如 GitHub 推出了新的自动化工具或功能。如果在某些时间段内 bot 账号的创建数量突然下降，可能是因为 GitHub 对 bot 账号的审核和管理政策发生了变化。
# Out:
# C:\Users\flipp\AppData\Local\Temp\ipykernel_4228\895935720.py:77: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   human_data['created_at'] = pd.to_datetime(human_data['created_at'])
# C:\Users\flipp\AppData\Local\Temp\ipykernel_4228\895935720.py:80: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   human_data['year_month'] = human_data['created_at'].dt.to_period('M')
# C:\Users\flipp\AppData\Local\Temp\ipykernel_4228\895935720.py:80: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
#4.4 可视化bot类型账号的followers和following情况（展示图表自选，并在报告中说明选择原因、结果分析以及数据洞察）
import pandas as pd
import matplotlib.pyplot as plt

# 读取CSV文件
raw_data = pd.read_csv('github_bot_raw_data.csv')

# 定义列字段
columns = [
    'actor_id',  # GitHub用户的ID
    'label',  # 用户标签（"Human"或"Bot"）
    'login',  # GitHub用户的登录名
    'id',  # 用户的GitHub ID
    'node_id',  # 用户的GitHub节点ID
    'avatar_url',  # GitHub头像URL
    'gravatar_id',  # Gravatar ID
    'url',  # GitHub用户的URL
    'html_url',  # GitHub用户的HTML URL
    'followers_url',  # GitHub用户的粉丝URL
    'following_url',  # GitHub用户的关注URL
    'gists_url',  # 用户的GitHub Gists URL
    'starred_url',  # 用户的GitHub Starred URL
    'subscriptions_url',  # 用户的GitHub订阅URL
    'organizations_url',  # 用户的GitHub组织URL
    'repos_url',  # 用户的GitHub仓库URL
    'events_url',  # 用户的GitHub事件URL
    'received_events_url',  # 用户的GitHub接收事件URL
    'type',  # 用户类型，通常为"User"
    'site_admin',  # 表示用户是否是GitHub网站管理员的标志
    'name',  # 用户的姓名
    'company',  # 用户所在公司
    'blog',  # 用户的博客
    'location',  # 用户的位置
    'email',  # 用户的电子邮件
    'hireable',  # 表示用户是否愿意被雇佣的标志
    'bio',  # 用户在其GitHub资料中提供的自我介绍或个人简介
    'twitter_username',  # 用户的Twitter用户名
    'public_repos',  # 用户在GitHub上的公共代码仓库数量
    'public_gists',  # 用户的公共Gists数量
    'followers',  # 关注该用户的其他GitHub用户数量
    'following',  # 该用户关注的其他GitHub用户数量
    'created_at',  # 用户的GitHub帐户创建日期
    'updated_at'  # 用户的GitHub帐户最后更新日期
]

# 选择指定的列
data = raw_data[columns]

# 删除重复数据
data = data.drop_duplicates()

# 去掉 gravatar_id 列
data = data.drop(columns=['gravatar_id'])

# 将可转化成 boolean 变量的列字段转化成 boolean 变量
boolean_columns = ['company', 'blog', 'location', 'email', 'hireable', 'bio', 'twitter_username']
for col in boolean_columns:
    data[col] = ~data[col].isnull()

# 文本数据用空字符串填充空值
text_columns = ['name', 'company', 'blog', 'location', 'email', 'bio', 'twitter_username']
for col in text_columns:
    data[col] = data[col].fillna('')

data['created_at'] = pd.to_datetime(data['created_at'], errors='coerce')  
data['updated_at'] = pd.to_datetime(data['updated_at'], errors='coerce')

data['created_at_timestamp'] = data['created_at'].view('int64') // 10**9
data['updated_at_timestamp'] = data['updated_at'].view('int64') // 10**9
# 查看 label 列的分布情况
label_counts = data['label'].value_counts()

# 筛选出bot类型的账号
bot_data = data[data['label'] == 'Bot']

# 生成箱线图
plt.figure(figsize=(12, 6))

# 绘制followers的箱线图
plt.subplot(1, 2, 1)
plt.boxplot(bot_data['followers'], vert=False)
plt.title('Distribution of Followers for Bot Accounts')
plt.xlabel('Number of Followers')
plt.yticks([])

# 绘制following的箱线图
plt.subplot(1, 2, 2)
plt.boxplot(bot_data['following'], vert=False)
plt.title('Distribution of Following for Bot Accounts')
plt.xlabel('Number of Following')
plt.yticks([])

plt.tight_layout()
plt.show()

#选择原因：箱线图适合展示数据的分布情况，包括中位数、上下四分位数、异常值等。
#结果分析：followers数量集中在0-1000之间，following数量也基本在0-300之间。
#数据洞察：大多数 bot 账号的 followers 和 following 数量集中在某个范围内,但也有一些异常值。

# %%
# 4.5可视化human类型账号的followers和following情况（展示图表自选，并在报告中说明选择原因、结果分析以及数据洞察）
import pandas as pd
import matplotlib.pyplot as plt

# 读取CSV文件
raw_data = pd.read_csv('github_bot_raw_data.csv')

# 定义列字段
columns = [
    'actor_id',  # GitHub用户的ID
    'label',  # 用户标签（"Human"或"Bot"）
    'login',  # GitHub用户的登录名
    'id',  # 用户的GitHub ID
    'node_id',  # 用户的GitHub节点ID
    'avatar_url',  # GitHub头像URL
    'gravatar_id',  # Gravatar ID
    'url',  # GitHub用户的URL
    'html_url',  # GitHub用户的HTML URL
    'followers_url',  # GitHub用户的粉丝URL
    'following_url',  # GitHub用户的关注URL
    'gists_url',  # 用户的GitHub Gists URL
    'starred_url',  # 用户的GitHub Starred URL
    'subscriptions_url',  # 用户的GitHub订阅URL
    'organizations_url',  # 用户的GitHub组织URL
    'repos_url',  # 用户的GitHub仓库URL
    'events_url',  # 用户的GitHub事件URL
    'received_events_url',  # 用户的GitHub接收事件URL
    'type',  # 用户类型，通常为"User"
    'site_admin',  # 表示用户是否是GitHub网站管理员的标志
    'name',  # 用户的姓名
    'company',  # 用户所在公司
    'blog',  # 用户的博客
    'location',  # 用户的位置
    'email',  # 用户的电子邮件
    'hireable',  # 表示用户是否愿意被雇佣的标志
    'bio',  # 用户在其GitHub资料中提供的自我介绍或个人简介
    'twitter_username',  # 用户的Twitter用户名
    'public_repos',  # 用户在GitHub上的公共代码仓库数量
    'public_gists',  # 用户的公共Gists数量
    'followers',  # 关注该用户的其他GitHub用户数量
    'following',  # 该用户关注的其他GitHub用户数量
    'created_at',  # 用户的GitHub帐户创建日期
    'updated_at'  # 用户的GitHub帐户最后更新日期
]

# 选择指定的列
data = raw_data[columns]

# 删除重复数据
data = data.drop_duplicates()

# 去掉 gravatar_id 列
data = data.drop(columns=['gravatar_id'])

# 将可转化成 boolean 变量的列字段转化成 boolean 变量
boolean_columns = ['company', 'blog', 'location', 'email', 'hireable', 'bio', 'twitter_username']
for col in boolean_columns:
    data[col] = ~data[col].isnull()

# 文本数据用空字符串填充空值
text_columns = ['name', 'company', 'blog', 'location', 'email', 'bio', 'twitter_username']
for col in text_columns:
    data[col] = data[col].fillna('')

data['created_at'] = pd.to_datetime(data['created_at'], errors='coerce')  
data['updated_at'] = pd.to_datetime(data['updated_at'], errors='coerce')

data['created_at_timestamp'] = data['created_at'].view('int64') // 10**9
data['updated_at_timestamp'] = data['updated_at'].view('int64') // 10**9
# 查看 label 列的分布情况
label_counts = data['label'].value_counts()

# 筛选出human类型的账号
human_data = data[data['label'] == 'Human']

# 生成箱线图
plt.figure(figsize=(12, 6))

# 绘制followers的箱线图
plt.subplot(1, 2, 1)
plt.boxplot(human_data['followers'], vert=False)
plt.title('Distribution of Followers for Human Accounts')
plt.xlabel('Number of Followers')
plt.yticks([])

# 绘制following的箱线图
plt.subplot(1, 2, 2)
plt.boxplot(human_data['following'], vert=False)
plt.title('Distribution of Following for Human Accounts')
plt.xlabel('Number of Following')
plt.yticks([])

plt.tight_layout()
plt.show()

#选择原因：箱线图适合展示数据的分布情况，包括中位数、上下四分位数、异常值等。
#结果分析：followers数量集中在0-20000之间，following数量也基本在0-5000之间。
#数据洞察：大多数 human 账号的 followers 和 following 数量集中在某个范围内,但也有一些异常值。
